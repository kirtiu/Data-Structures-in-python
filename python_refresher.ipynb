# %% [markdown]
# 1.Built in datatypes  and data structure

# %% [markdown]
# 1.1 Numeric Types

# %%
a=10
type(a)
# Out:
# int

# %%
a=24.0
type(a)
# Out:
# float

# %%
a=5+3j
type(a)
# Out:
# complex

# %% [markdown]
# 1.2 Sequence Types

# %%
a="This is a Kirti"
type(a)
# Out:
# str

# %%
b='this is a kirti'
type(b)
# Out:
# str

# %%
c='''this is a kirti'''
type(c)
# Out:
# str

# %%
li=[1,2,3,4,'kirti',2+6j]
type(li)
# Out:
# list

# %%
t=(1,2,3)
type(t)
# Out:
# tuple

# %%
t1=1,2,3
type(t1)
# Out:
# tuple

# %%
z=(6.5,6.4,7.7)
type(z)
# Out:
# tuple

# %% [markdown]
# 1.3 Set Types

# %%
s1={1,2,3}
type(s1)
# Out:
# set

# %%
s1={1,2,3,3,3,4,4,4,5,6}
type(s1)
# Out:
# set

# %%
s3=frozenset({1,2})
type(s3)
# Out:
# frozenset

# %% [markdown]
# 1.4 Mapping Types

# %%
d={
    'name':'kirti',
    'occupation':'Engineer'
}
type(d)
# Out:
# dict

# %% [markdown]
# 1.5 Boolean Types

# %%
a=True
type(a)
# Out:
# bool

# %% [markdown]
# 1.6 None Type

# %%
a=None
type(a)
# Out:
# NoneType

# %% [markdown]
# 2. Control Structures

# %% [markdown]
# 2.1 if-else

# %%
a=-1
if a>5:
    print('Greater than 5')
else:
    print('not greater than 5')
# Out:
# not greater than 5

# %%
a=8
if a%2==0:
    print('even')
else:
    print('odd')
# Out:
# even

# %% [markdown]
# 2.2 if-elif-else

# %%
marks=26
if marks>90:
    print('excellent')
elif marks >70:
    print('very good')
elif marks>50:
    print('good')
else:
    print('bad')
# Out:
# bad

# %% [markdown]
# 3.Loops

# %% [markdown]
# 3.1 For loop

# %%
li=[1,2,3,4]
print(li[0])
print(li[1])
# Out:
# 1
# 2

# %%
for element in li:
    print(element)
# Out:
# 1
# 2
# 3
# 4

# %%
for element in range(20,31):
    if element % 2==0:
        print(element)
# Out:
# 20
# 22
# 24
# 26
# 28
# 30

# %%
for element in range(20,31,2):
    print(element)
# Out:
# 20
# 22
# 24
# 26
# 28
# 30

# %% [markdown]
# 3.2 While loop

# %%
a=1
while a<=5:
    print(a)
    a+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# 4.Functions

# %% [markdown]
# 4.1 Definition/cell

# %%
def random_func():
    print('This is a random function')

# %%
random_func()
# Out:
# This is a random function

# %%
def ad_numbers():
    a=2+3
    print(a)

# %%
ad_numbers()
# Out:
# 5

# %% [markdown]
# 4.2 Input to Functions

# %%
def add_2_numbers(a,b):
    print(f'sum of {a} and {b} is {a+b}')

# %%
add_2_numbers(5,6)
# Out:
# sum of 5 and 6 is 11

# %%
def greeting(name):
    print(f'Hi {name}, good morning')

# %%
greeting('Jack')
# Out:
# Hi Jack, good morning

# %% [markdown]
# 4.3 Output from functions

# %%
def add_two_numbers(a,b):
    res=a+b
    print(f'sum of {a} and {b} is {res}')
    return res

# %%
c=add_two_numbers(4,5)
# Out:
# sum of 4 and 5 is 9

# %%
print(c)
# Out:
# 9

# %% [markdown]
# 5. Built in Functions

# %%
li=[5,6,7,8,9]

# %%
min(li)
# Out:
# 5

# %%
min((3,4,-4,-2,6,0))
# Out:
# -4

# %%
min(['kitty','venytyui'])
# Out:
# 'kitty'

# %%
max(li)
# Out:
# 6

# %%
sum(li)
# Out:
# 7

# %%
len(li)
# Out:
# 6

# %%
len(['asc','fh','yui'])
# Out:
# 3

# %%
sum(li)/len(li)
# Out:
# 1.1666666666666667

# %% [markdown]
# 5.5 sorted

# %%
li
# Out:
# (3, 4, -4, -2, 6, 0)

# %%
sorted(li)
# Out:
# [-4, -2, 0, 3, 4, 6]

# %% [markdown]
# 5.6 enumerate

# %%
names=['bruce','peter','barry','steve']

# %%
list(range(len(names)))
# Out:
# [0, 1, 2, 3]

# %%
for i in range(len(names)):
    print(i,names[i])
# Out:
# 0 bruce
# 1 peter
# 2 barry
# 3 steve

# %%
for i,name in enumerate(names):
    print(i,name)
# Out:
# 0 bruce
# 1 peter
# 2 barry
# 3 steve

# %% [markdown]
# 5.7 zip

# %%
names
# Out:
# ['bruce', 'peter', 'barry', 'steve']

# %%
colors=['red','orange','pink','green']
ages=[24,56,78,56]

# %%
for name,age,color in zip(names,ages,colors):
    print(f'{name} is {age} years old and they like the color{color}.')
# Out:
# bruce is 24 years old and they like the colorred.
# peter is 56 years old and they like the colororange.
# barry is 78 years old and they like the colorpink.

# %% [markdown]
# 6. List Comprehensios

# %%
result=[]

for i in range(1,11):
    if i %2==0:
        result.append(i)
result
# Out:
# [2, 4, 6, 8, 10]

# %%
list(range(2,11,2))
# Out:
# [2, 4, 6, 8, 10]

# %%
seq=range(1,11)
[a for a in seq if a%2==0]
# Out:
# [2, 4, 6, 8, 10]

# %% [markdown]
# 7. Classes

# %%
class MyRectangle:
    def __init__(self,length,breadth):
        self.length=length
        self.breadth=breadth
        self.random_attribute=0
        self.another_random_attribute='abc'
    def get_perimeter(self):
        return 2*(self.length+self.breadth)
    def get_area(self):
        return self.length*self.breadth
    def get_length(self):
        return self.length
    def get_breadth(self):
        return self.breadth

# %%
obj1=MyRectangle(length=5,breadth=6)

# %%
obj2=MyRectangle(length=5,breadth=6)

# %%
obj1

# %%
obj1.breadth
# Out:
# 6

# %%
obj1.random_attribute
# Out:
# 0

# %%
obj1.another_random_attribute
# Out:
# 'abc'

# %%
obj2.get_area(h)
# Out:
# 30

# %%
obj1.get_area()
# Out:
# 30
